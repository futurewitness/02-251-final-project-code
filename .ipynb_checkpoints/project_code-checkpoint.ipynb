# %%
import Pyfhel
import numpy as np
import matplotlib as plt
import math
import copy
from IPython.core.display import display, HTML

# %%
display(HTML('<h1>Algorithm for Seed and Extend</h1>'))
# Out:
# <h1>Algorithm for Seed and Extend</h1>

# %%
display(HTML("<h2>Start by Seeding on the User's end</h2>"))
# Out:
# <h2>Start by Seeding on the User's end</h2>

# %%
#Get user query string
g = open("genome.txt","r")
q = open("query.txt","r")
k = 3
t = 2
bases = ['a','c','g','t']
query = q.read()
split_query = [query[i:i+k] for i in range(0,len(query)-k)]
#Make the Evaluation function using the +2/-3 for match/mismatch
#print(split_query)
threshold = int(0.6 * len(split_query[0]))
#print(threshold)
valid_seeds = []
def permute(str,arr,depth,valid_seeds):
    if depth == threshold:
        return
    for i in range(0,len(str)):
        if i in arr:
            continue
        arr.append(i)
        for j in bases:
            valid_seeds.append(str[:i] + j + str[i+1:])
            permute(str[:i] + j + str[i+1:],arr,depth+1,valid_seeds)
        arr.remove(i)
seeds = []
for i in split_query:
    valid_seeds = []
    permute(i,[],0,valid_seeds)
    valid_seeds = set(valid_seeds)
    seeds.append(valid_seeds)
#total_seeds.append()
print(seeds)
# Out:
# [{'ctt', 'ctc', 'cca', 'cga', 'caa', 'gta', 'cta', 'ata', 'ctg', 'tta'}, {'taa', 'caa', 'tag', 'gaa', 'aaa', 'tca', 'tga', 'tac', 'tat', 'tta'}, {'taa', 'aca', 'caa', 'aac', 'gaa', 'ata', 'aaa', 'aat', 'aga', 'aag'}, {'cac', 'gac', 'acc', 'aac', 'agc', 'atc', 'aaa', 'aat', 'tac', 'aag'}, {'gca', 'aca', 'cca', 'act', 'acc', 'acg', 'ata', 'aaa', 'tca', 'aga'}, {'cac', 'caa', 'tag', 'gag', 'cag', 'cat', 'ccg', 'cgg', 'aag', 'ctg'}, {'agg', 'agt', 'tgt', 'act', 'ggt', 'agc', 'aat', 'aga', 'att', 'cgt'}, {'ctc', 'gtg', 'ttc', 'gtt', 'gac', 'gtc', 'gta', 'gcc', 'ggc', 'atc'}]

# %%
display(HTML("<h2>Begin testing seeds against genome</h2>"))
# Out:
# <h2>Begin testing seeds against genome</h2>

# %%
class sequence:
    def __init__(self,cipher,ranges,scores,origin=0):
        self.c_text = cipher
        self.ranges = ranges
        self.diffs = []
        self.scores = scores
        self.origin = origin
#compare seeds against genome
test_genome = "tacatacatacataca"
z = Pyfhel.Pyfhel()
z.contextGen(p=40961, m=4096, flagBatching=True)
z.keyGen()
z.rotateKeyGen(20)
test_seed ="taca"
genome_split = [ ord(i) for i in test_genome]
test_split = [ ord(i) for i in test_seed]
size = len(test_genome) - len(test_seed)
start = 0
end = len(test_seed)
for i in range(0,size-len(test_split)):
    test_split.append(0)
e_genome = z.encrypt(z.encodeBatch(genome_split))
e_test = [sequence(z.encrypt(z.encodeBatch(test_split)),[],[])]
e_vectors = []
def get_differences(seeds,genome,score):
    start = 0
    end = len(test_seed)
    rotate_seeds = [Pyfhel.PyCtxt(i.c_text) for i in seeds]
    for k in range(0,size):
        diff_seeds = [Pyfhel.PyCtxt(i) for i in rotate_seeds]
        rotate_seeds = [Pyfhel.PyCtxt(i) for i in rotate_seeds]
        diffs = [z.sub(diff_seeds[i],genome) for i in range(0,len(seeds))]
        for d in range(0,len(seeds)):
            seeds[d].ranges.append((start,end))
            seeds[d].diffs.append(diffs[d])
            seeds[d].scores.append(score)
        rotate_seeds = [z.rotate(rotate_seeds[i],2000) for i in range(0,len(seeds))]
        rotate_seeds = [z.rotate(rotate_seeds[i],2000) for i in range(0,len(seeds))]
        rotate_seeds = [z.rotate(rotate_seeds[i],95) for i in range(0,len(seeds))]
        start += 1
        end += 1
        #print(z.decode(z.decrypt(genome))[:size+20])
def decrypt_differences(candidates):
    start = 0
    end = len(test_seed)
    for i in candidates:
        print(z.decodeBatch(z.decrypt(i))[start:end])
        start +=1
        end += 1
get_differences(e_test,e_genome,4)
print(e_test[0].ranges)
print(len(e_test[0].ranges))
print([z.decode(z.decrypt(e_test[0].diffs[i]))[e_test[0].ranges[i][0]:e_test[0].ranges[i][1]] for i in range(0,len(e_test[0].diffs))])
#decrypt_differences(e_vectors)
# Out:
# [(0, 4), (1, 5), (2, 6), (3, 7), (4, 8), (5, 9), (6, 10), (7, 11), (8, 12), (9, 13), (10, 14), (11, 15)]
# 12
# [[0, 0, 0, 0], [19, -2, 2, -19], [17, 0, -17, 0], [19, -19, 2, -2], [0, 0, 0, 0], [19, -2, 2, -19], [17, 0, -17, 0], [19, -19, 2, -2], [0, 0, 0, 0], [19, -2, 2, -19], [17, 0, -17, 0], [19, -19, 2, -2]]

# %%
display(HTML("<h2>Extend the Seeds</h2>"))
# Out:
# <h2>Extend the Seeds</h2>

# %%
test_genome = "gctacacacacacacacaacat"
query = "aactactcactgc"
q_size = len(query)
query = z.encrypt(z.encodeBatch([ ord(i) for i in query]))
test_seed = "cta"
test_split = [ ord(i) for i in test_seed]
test_seq = sequence(z.encrypt(z.encodeBatch(test_split)),[(1,3)],[4],[(2,4)])
#print(test_seq.ranges)
def check_seq(index1,index2,cipher,genome,cipher_size):
    x = z.decode(z.decrypt(cipher))[index2]
    print( str(index1) +" " +  str(index2))
    return  ord(genome[index1]) - x == 0
    
def extend_seeds(seq,query,genome,cipher_size):
    for i in range(0,len(seq.ranges)):
        left = seq.ranges[i][0]
        right = seq.ranges[i][1]
        index = left-1
        while(index >= 0 and check_seq(index,seq.origin[i][0]-1,query,genome,cipher_size)):
            seq.ranges[i] = (seq.ranges[i][0]-1,seq.ranges[i][1])
            seq.origin[i] = (seq.origin[i][0]-1,seq.origin[i][1])
            index -= 1
            seq.scores[i] += 2
            print(index)
            
        index = right+1
        
        while(index < len(genome) and check_seq(index,seq.origin[i][1]+1,query,genome,cipher_size)):
            seq.ranges[i] = (seq.ranges[i][0],seq.ranges[i][1]+1)
            seq.origin[i] = (seq.origin[i][0],seq.origin[i][1]+1)
            index += 1
            seq.scores[i] += 2
extend_seeds(test_seq,query,test_genome,q_size)

print(test_seq.ranges)
# Out:
# 0 1
# 4 5
# 5 6
# [(1, 4)]

# %%
display(HTML("<h2>Merge Signficant seeds</h2>"))
# Out:
# <h2>Merge Signficant seeds</h2>

# %%
def getFirst(elem):
    return elem[0]
def getSecond(elem):
    return elem[1]
def find_intersections(intervals):
    starts = intervals[:]
    starts.sort(key=getFirst)
    begin = starts[0][0]
    end = starts[0][1]
    final_intervals = []
    for interval in starts:
        if interval[0] > end:
            final_intervals.append((begin,end))
            begin = interval[0]
            end = interval[1]
        else:
            end = max(interval[1],end)
    final_intervals.append((begin,end))
    return final_intervals
interval = [(1,2),(3,7),(4,6),(4,9)]
find_intersections(interval)
# Out:
# [(1, 2), (3, 9)]

# %%
display(HTML("<h2>Putting it all together</h2>"))
# Out:
# <h2>Putting it all together</h2>

# %%
class sequence:
    def __init__(self,decrypt,cipher,ranges,scores,origin=0):
        self.decrypted = decrypt
        self.length = len(self.decrypted)
        self.c_text = cipher
        self.ranges = ranges
        self.diffs = []
        self.scores = scores
        self.origin = origin

g = open("genome.txt","r")
q = open("query.txt","r")
k = 5
t = 2
test_genome = g.read()
z = Pyfhel.Pyfhel()
#p=163841,m=16384
z.contextGen(p=40961,m=4096,flagBatching=True)
z.keyGen()
z.rotateKeyGen(40)
z.relinKeyGen(40,20)
bases = ['a','c','g','t']
query = q.read()
split_query = [(query[i:i+k],(i,i+k-1)) for i in range(0,len(query)-k)]
#Make the Evaluation function using the +2/-3 for match/mismatch
#print(split_query)
threshold = int(0.2 * len(split_query[0][0]))
#print(threshold)


def permute(str,arr,depth,valid_seeds):
    if depth == threshold:
        return
    for i in range(0,len(str)):
        if i in arr:
            continue
        arr.append(i)
        for j in bases:
            valid_seeds.append((str[:i] + j + str[i+1:],depth+1))
            permute(str[:i] + j + str[i+1:],arr,depth+1,valid_seeds)
        arr.remove(i)
        
seeds = []
for i in split_query:
    valid_seeds = []
    permute(i[0],[],0,valid_seeds)
    valid_seeds.append((i[0],0))
    valid_seeds = set(valid_seeds)
    #print(valid_seeds)
    for j in valid_seeds:
        encrypted_seed = z.encrypt(z.encodeBatch([ord(m) for m in j[0]]))
        score = (len(i[0])- j[1]) * 2
        seeds.append(sequence(j[0],encrypted_seed,[],[score],[i[1]]))
#print(valid_seeds)

###############################################################################



#compare seeds against genome
#print(test_genome)
size = len(test_genome)
' '.join(test_genome.split())
genome_split = [ ord(i) for i in test_genome]
print(test_genome)
e_genome = z.encrypt(z.encodeBatch(genome_split))
def get_differences(seqs,genome,size):
    start = 0
    end = seqs[0].length
    rotate_seeds = [Pyfhel.PyCtxt(i.c_text) for i in seqs]
    for k in range(0,size):
        diff_seeds = [Pyfhel.PyCtxt(i) for i in rotate_seeds]
        rotate_seeds = [Pyfhel.PyCtxt(i) for i in rotate_seeds]
        diffs = [z.sub(diff_seeds[i],genome) for i in range(0,len(seqs))]
        for d in range(0,len(seqs)):
            seqs[d].ranges.append((start,end))
            seqs[d].origin.append(seeds[d].origin[0])
            seqs[d].diffs.append(diffs[d])
            seqs[d].scores.append(score)
        rotate_seeds = [z.rotate(rotate_seeds[i],-1) for i in range(0,len(seeds))]
        #rotate_seeds = [z.rotate(rotate_seeds[i],2000) for i in range(0,len(seeds))]
        #rotate_seeds = [z.rotate(rotate_seeds[i],95) for i in range(0,len(seeds))]
        start += 1
        end += 1
        #print(start)
        #print(z.decode(z.decrypt(genome))[:size+20])
#print(seeds)
get_differences(seeds,e_genome,size)
#print(seeds[0].ranges)

for seed in seeds:
    seed.origin.pop()
    rem = []
    for r in range(0,len(seed.ranges)):
        a = z.decode(z.decrypt(seed.diffs[r]))[seed.ranges[r][0]:seed.ranges[r][1]]
        for j in range(0,len(a)):
            if a[j] != 0:
                rem.append(r)
                break
    seed.origin = [seed.origin[ele] for ele in range(0,len(seed.origin)) if ele not in rem] 
    seed.ranges = [seed.ranges[ele] for ele in range(0,len(seed.ranges)) if ele not in rem] 
    seed.diffs = [seed.diffs[ele] for ele in range(0,len(seed.diffs)) if ele not in rem] 
    seed.scores = [seed.scores[ele] for ele in range(0,len(seed.scores)) if ele not in rem] 
    
            
#######################################################################################################
#print("Hello")
q_size = len(query)
query = z.encrypt(z.encodeBatch([ ord(i) for i in query]))
#print(test_seq.ranges)
#print("Hello")
def check_seq(index1,index2,cipher,genome,cipher_size):
    x = z.decode(z.decrypt(cipher))[index2]
    #print( str(index1) +" " +  str(index2))
    return  ord(genome[index1]) - x == 0

def extend_seeds(seqs,query,genome,cipher_size):
    for seq in seqs:
        #print(seq.ranges)
        #print("HEllo")
        for i in range(0,len(seq.ranges)):
            #print(seq.ranges)
            left = seq.ranges[i][0]
            right = seq.ranges[i][1]
            index = left-1

            while(index >= 0 and check_seq(index,seq.origin[i][0]-1,query,genome,cipher_size)):
                seq.ranges[i] = (seq.ranges[i][0]-1,seq.ranges[i][1])
                seq.origin[i] = (seq.origin[i][0]-1,seq.origin[i][1])
                index -= 1
                #print(seq.scores)
                seq.scores[i] += 2
                #print(index)

            index = right+1

            while(index < len(genome) and check_seq(index,seq.origin[i][1]+1,query,genome,cipher_size)):
                seq.ranges[i] = (seq.ranges[i][0],seq.ranges[i][1]+1)
                seq.origin[i] = (seq.origin[i][0],seq.origin[i][1]+1)
                index += 1
                seq.scores[i] += 2

            
extend_seeds(seeds,query,test_genome,q_size)

for i in seeds:
    #print(i.scores)
    if len(i.ranges) == 0:
        del i
print("extended")
###############################################################################

intervals = []
for seed in range(0,len(seeds)):
    for j in range(0,len(seeds[seed].ranges)):
        intervals.append((seeds[seed].ranges[j],seed,seeds[seed].origin[j]))
def getFirst(elem):
    return elem[0][0]
def find_intersections(intervals):
    starts = intervals[:]
    print(starts)
    starts.sort(key=getFirst)
    begin = starts[0][0][0]
    end = starts[0][0][1]
    o_begin = starts[0][2][0]
    o_end = starts[0][2][1]
    final_intervals = []
    used = set()
    for interval in starts:
        if interval[1] in used:
            continue 
        if interval[0][0] > end:
            final_intervals.append((begin,end,o_begin,o_end+2))
            begin = interval[0][0]
            end = interval[0][1]
            o_begin = interval[2][0]
            o_end = interval[2][1]
            used = set()
        else:
            print(interval)
            end = max(interval[0][1],end)
            o_end = max(interval[2][1],o_end)
            used.add(interval[1])
    final_intervals.append((begin,end,o_begin,o_end+1))
    return final_intervals

intervals = find_intersections(intervals)
print(intervals)           

print("intervals found")
#################################################################################

def check_intersections(intersections,query,genome):
    merge = set()
    final_intervals = []
    for i in range(0,len(intersections)-1):
        g_start = intersections[i][0]
        g_end = intersections[i+1][2]
        q_start = intersections[i][1]
        q_end = intersections[i+1][3]
        a = z.decode(z.decrypt(query))[q_start:q_end]
        x = genome[g_start:g_end]
        neg = 0
        for j in range(0,q_end-q_start):
            if a[j] != x[j]:
                neg += 2
        if neg  < (3*(g_end-g_start)):
            merge.add(i)
    for j in range(0,len(merge)-1):
        begin = j
        end = j+1
        while merge[j+1] == merge[j] + 1:
            end += 1
            del intersections[j]
        for k in range(0,len(intersections)):
            if intersectiop
            final_intervals.append(intersections[k])
        final_intervals.append(intersections[start][0],intersections[end][1],intersections[start][2],intersections[end][3])
    return final_intervals 

check_intersections(intervals,query,test_genome)
##########################################################################################
# Out:
#   File "<ipython-input-14-2ed3565a9aed>", line 216
#     if intersectiop
#                    ^
# SyntaxError: invalid syntax

# %%
display(HTML("<h1>Finding primes that enable array batching<\h1>"))

# %%
infile = open("primes","r")

x = infile.read().split()
x = [ int(i) for i in x]
#for i in x:
    #for j in range(2,i):
        #print(i)
        #for k in range(2,9):
            #if ((i-1) % (2*j) == 0 and math.log(j,k).is_integer()): 
                #print((i,j,k,(i-1)/j))
# Out:
# (349717, 2, 2, 174858.0)
# (349717, 3, 3, 116572.0)
# (349717, 6, 6, 58286.0)
# (349729, 2, 2, 174864.0)
# (349729, 3, 3, 116576.0)
# (349729, 4, 2, 87432.0)
# (349729, 4, 4, 87432.0)
# (349729, 6, 6, 58288.0)
# (349729, 8, 2, 43716.0)
# (349729, 8, 8, 43716.0)
# (349729, 16, 2, 21858.0)
# (349729, 16, 4, 21858.0)
# (349753, 2, 2, 174876.0)
# (349753, 3, 3, 116584.0)
# (349753, 4, 2, 87438.0)
# (349753, 4, 4, 87438.0)
# (349753, 6, 6, 58292.0)
# (349759, 3, 3, 116586.0)
# (349759, 9, 3, 38862.0)
# (349759, 27, 3, 12954.0)
# (349759, 81, 3, 4318.0)
# (349793, 2, 2, 174896.0)
# (349793, 4, 2, 87448.0)
# (349793, 4, 4, 87448.0)
# (349793, 8, 2, 43724.0)
# (349793, 8, 8, 43724.0)
# (349793, 16, 2, 21862.0)
# (349793, 16, 4, 21862.0)
# (349801, 2, 2, 174900.0)
# (349801, 3, 3, 116600.0)
# (349801, 4, 2, 87450.0)
# (349801, 4, 4, 87450.0)
# (349801, 5, 5, 69960.0)
# (349801, 6, 6, 58300.0)
# (349801, 25, 5, 13992.0)
# (349813, 2, 2, 174906.0)
# (349813, 3, 3, 116604.0)
# (349813, 6, 6, 58302.0)
# (349813, 9, 3, 38868.0)
# (349813, 27, 3, 12956.0)
# (349819, 3, 3, 116606.0)
# (349819, 7, 7, 49974.0)
# (349829, 2, 2, 174914.0)
# (349831, 3, 3, 116610.0)
# (349831, 5, 5, 69966.0)
# (349831, 9, 3, 38870.0)
# (349837, 2, 2, 174918.0)
# (349837, 3, 3, 116612.0)
# (349837, 6, 6, 58306.0)
# (349841, 2, 2, 174920.0)
# (349841, 4, 2, 87460.0)
# (349841, 4, 4, 87460.0)
# (349841, 5, 5, 69968.0)
# (349841, 8, 2, 43730.0)
# (349841, 8, 8, 43730.0)
# (349849, 2, 2, 174924.0)
# (349849, 3, 3, 116616.0)
# (349849, 4, 2, 87462.0)
# (349849, 4, 4, 87462.0)
# (349849, 6, 6, 58308.0)
# (349849, 9, 3, 38872.0)
# (349849, 36, 6, 9718.0)
# (349871, 5, 5, 69974.0)
# (349903, 3, 3, 116634.0)
# (349903, 7, 7, 49986.0)
# (349903, 9, 3, 38878.0)
# (349913, 2, 2, 174956.0)
# (349913, 4, 2, 87478.0)
# (349913, 4, 4, 87478.0)
# (349927, 3, 3, 116642.0)
# (349931, 5, 5, 69986.0)
# (349931, 7, 7, 49990.0)
# (349933, 2, 2, 174966.0)
# (349933, 3, 3, 116644.0)
# (349933, 6, 6, 58322.0)
# (349939, 3, 3, 116646.0)
# (349939, 9, 3, 38882.0)
# (349949, 2, 2, 174974.0)
# (349963, 3, 3, 116654.0)
# (349981, 2, 2, 174990.0)
# (349981, 3, 3, 116660.0)
# (349981, 5, 5, 69996.0)
# (349981, 6, 6, 58330.0)

# %%
kmers = open("kmers.txt","w")
print(test_genome)
x = [test_genome[i:i+k] for i in range(0,len(test_genome)-k)]
y = [test_genome[i:i+k] for i in range(0,len(queery)-k)]
kmers.write(str(x))
kmers.write("\n")
kmers.write(str(y))
kmers.close()
print(x)

# %%
class sequence:
    def __init__(self,decrypt,cipher,ranges,scores,origin=0):
        self.decrypted = decrypt
        self.length = len(self.decrypted)
        self.c_text = cipher
        self.ranges = ranges
        self.diffs = []
        self.scores = scores
        self.origin = origin

g = open("genome.txt","r")
q = open("query.txt","r")
k = 4
t = 2
test_genome = g.read()
z = Pyfhel.Pyfhel()
z.contextGen(p=40961, m=4096, flagBatching=True)
z.keyGen()
z.rotateKeyGen(40)
z.relinKeyGen(40,20)
bases = ['a','c','g','t']
queery = q.read()
query = queery[:]
split_query = [(query[i:i+k],(i,i+k-1)) for i in range(0,len(query)-k)]
#Make the Evaluation function using the +2/-3 for match/mismatch
#print(split_query)
threshold = int(0.2 * len(split_query[0][0]))
#print(threshold)


def permute(str,arr,depth,valid_seeds):
    if depth == threshold:
        return
    for i in range(0,len(str)):
        if i in arr:
            continue
        arr.append(i)
        for j in bases:
            valid_seeds.append((str[:i] + j + str[i+1:],depth+1))
            permute(str[:i] + j + str[i+1:],arr,depth+1,valid_seeds)
        arr.remove(i)
        
seeds = []
for i in split_query:
    valid_seeds = []
    permute(i[0],[],0,valid_seeds)
    valid_seeds.append((i[0],0))
    valid_seeds = set(valid_seeds)
    #print(valid_seeds)
    for j in valid_seeds:
        encrypted_seed = z.encrypt(z.encodeBatch([ord(m) for m in j[0]]))
        score = (len(i[0])- j[1]) * 2
        seeds.append(sequence(j[0],encrypted_seed,[],[score],[i[1]]))
#print(valid_seeds)

###############################################################################



#compare seeds against genome
print(test_genome)
size = len(test_genome)
x = test_genome.split()
test_genome = ''.join(x)
print(test_genome)
genome_split = [ ord(i) for i in test_genome]
e_genome = z.encrypt(z.encodeBatch(genome_split))
def get_differences(seqs,genome,size):
    start = 0
    end = seqs[0].length
    rotate_seeds = [Pyfhel.PyCtxt(i.c_text) for i in seqs]
    for k in range(0,size):
        diff_seeds = [Pyfhel.PyCtxt(i) for i in rotate_seeds]
        rotate_seeds = [Pyfhel.PyCtxt(i) for i in rotate_seeds]
        diffs = [z.sub(diff_seeds[i],genome) for i in range(0,len(seqs))]
        for d in range(0,len(seqs)):
            seqs[d].ranges.append((start,end))
            seqs[d].origin.append(seeds[d].origin[0])
            seqs[d].diffs.append(diffs[d])
            seqs[d].scores.append(score)
        rotate_seeds = [z.rotate(rotate_seeds[i],-1) for i in range(0,len(seeds))]
        #rotate_seeds = [z.rotate(rotate_seeds[i],2000) for i in range(0,len(seeds))]
        #rotate_seeds = [z.rotate(rotate_seeds[i],95) for i in range(0,len(seeds))]
        start += 1
        end += 1
        #print(start)
        #print(z.decode(z.decrypt(genome))[:size+20])
#print(seeds)
get_differences(seeds,e_genome,size)
#print(seeds[0].ranges)
#print(differences_found)
for seed in seeds:
    seed.origin.pop()
    rem = []
    for r in range(0,len(seed.ranges)):
        a = z.decode(z.decrypt(seed.diffs[r]))[seed.ranges[r][0]:seed.ranges[r][1]]
        for j in range(0,len(a)):
            if a[j] != 0:
                rem.append(r)
                break
    seed.origin = [seed.origin[ele] for ele in range(0,len(seed.origin)) if ele not in rem] 
    seed.ranges = [seed.ranges[ele] for ele in range(0,len(seed.ranges)) if ele not in rem] 
    seed.diffs = [seed.diffs[ele] for ele in range(0,len(seed.diffs)) if ele not in rem] 
    seed.scores = [seed.scores[ele] for ele in range(0,len(seed.scores)) if ele not in rem] 
    
print("Seeds extended")
#####################################################################
#print("Hello")
q_size = len(query)
query = z.encrypt(z.encodeBatch([ ord(i) for i in query]))
#print(test_seq.ranges)
#print("Hello")
def check_seq(index1,index2,cipher,genome,cipher_size):
    x = z.decode(z.decrypt(cipher))[index2]
    #print( str(index1) +" " +  str(index2))
    return  ord(genome[index1]) - x == 0

def extend_seeds(seqs,query,genome,cipher_size):
    for seq in seqs:
        #print(seq.ranges)
        #print("HEllo")
        for i in range(0,len(seq.ranges)):
            #print(seq.ranges)
            left = seq.ranges[i][0]
            right = seq.ranges[i][1]
            index = left-1

            while(index >= 0 and check_seq(index,seq.origin[i][0]-1,query,genome,cipher_size)):
                seq.ranges[i] = (seq.ranges[i][0]-1,seq.ranges[i][1])
                seq.origin[i] = (seq.origin[i][0]-1,seq.origin[i][1])
                index -= 1
                #print(seq.scores)
                seq.scores[i] += 2
                #print(index)

            index = right+1

            while(index < len(genome) and check_seq(index,seq.origin[i][1]+1,query,genome,cipher_size)):
                seq.ranges[i] = (seq.ranges[i][0],seq.ranges[i][1]+1)
                seq.origin[i] = (seq.origin[i][0],seq.origin[i][1]+1)
                index += 1
                seq.scores[i] += 2

            
extend_seeds(seeds,query,test_genome,q_size)

for i in seeds:
    #print(i.scores)
    if len(i.ranges) == 0:
        del i

###############################################################################
intervals = []
for seed in range(0,len(seeds)):
    for j in range(0,len(seeds[seed].ranges)):
        intervals.append((seeds[seed].ranges[j],seed,seeds[seed].origin[j]))
def getFirst(elem):
    return elem[0][0]
def find_intersections(intervals):
    starts = intervals[:]
    print(starts)
    starts.sort(key=getFirst)
    begin = starts[0][0][0]
    end = starts[0][0][1]
    o_begin = starts[0][2][0]
    o_end = starts[0][2][1]
    final_intervals = []
    used = set()
    for interval in starts:
        if interval[1] in used:
            continue 
        if interval[0][0] > end:
            final_intervals.append((begin,end,o_begin,o_end+1))
            begin = interval[0][0]
            end = interval[0][1]
            o_begin = interval[2][0]
            o_end = interval[2][1]
            used = set()
        else:
            print(interval)
            end = max(interval[0][1],end)
            o_end = max(interval[2][1],o_end)
            used.add(interval[1])
    final_intervals.append((begin,end,o_begin,o_end+1))
    return final_intervals

intervals = find_intersections(intervals)
print(intervals)           

#################################################################################
def check_intersections(intersections,query,genome):
    for i in range(0,len(intersections)-1):
        g_start = intersections[i][0]
        g_end = intersections[i+1][2]
        q_start = intersections[i][1]
        q_end = intersections[i+1][3]
        merge = set()
        a = z.decode(z.decrypt(query))[q_start:q_end]
        x = genome[g_start:g_end]
        neg = 0
        final_intervals = []
        for j in range(0,q_end-q_start):
            if a[j] != x[j]:
                neg += 3
        if neg < (2*(g_end-g_start)):
            merge.add(i)
    for j in range(0,len(merge)-1):
        begin = j
        end = j+1
        while merge[j+1] == merge[j] + 1:
            end += 1
            del intersections[j]
        final_intervals.append(intersections[start][0],intersections[end][1],intersections[start][2],intersections[end][3])
    for m in range(0,len(intersections)):
        print(intersections[m])
        print(intersections[m][1]-intersections[m][0])
        if intersections[m][1]-intersections[m][0] >= k+2:
            final_intervals.append(intersections[m])
    return set(final_intervals) 

final_intervals = check_intersections(intervals,query,test_genome)
print(queery)
for i in final_intervals:
    print(i)
    print(test_genome[i[0]:i[1]])
    print(queery[i[2]:i[3]])
g.close()
q.close()
